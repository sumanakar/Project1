# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import requests
from census import Census
from us import states

# Census API Key
c = Census("85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98", year=2015)

# %%
# Census Search to retrieve data on all zip codes (2016)
# Analyze population, race age, income relationship with store location
census_data = c.acs5.get(("NAME",
                          "COUNTY",
                          "ST",
                          "ZCTA5",
                          "B19013_001E", 
                          "B01003_001E", 
                          "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B02001_002E",
                          "B02001_003E",
                          "B02001_004E",
                          "B02001_005E",
                          "B02001_006E",
                          "B02001_007E",
                          "B02001_008E",
                          "B02001_009E",
                          "B02001_010E",
                          "B01001A_002E",
                          "B01001A_017E",
                          "B01001B_002E",
                          "B01001B_017E",
                          "B01001C_002E",
                          "B01001C_017E",
                          "B01001D_002E",
                          "B01001D_017E",
                          "B01001E_002E",
                          "B01001E_017E",
                          "B01001F_002E",
                          "B01001F_017E",
                          "B01001G_002E",
                          "B01001G_017E",
                          "B01001H_002E",
                          "B01001H_017E",
                          "B01001I_002E",
                          "B01001I_017E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"NAME": "Name",
                                      "COUNTY": "County",
                                      "ST": "State",
                                      "ZCTA5": "Postcode",
                                      "B01003_001E": "Population", 
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B02001_002E": "Race White",
                                      "B02001_003E": "Race African American",
                                      "B02001_004E": "Race American Indian",
                                      "B02001_005E": "Race Asian",
                                      "B02001_006E": "Race Pacific Islander",
                                      "B02001_007E": "Race Some Other",
                                      "B02001_008E": "Race Two or More",
                                      "B02001_009E": "Race Two or More Including Some Other",
                                      "B02001_010E": "Race Two or More Excluding Some Other",
                                      "B01001A_002E": "Male White",
                                      "B01001A_017E": "Female White",
                                      "B01001B_002E": "Male African",
                                      "B01001B_017E": "Female African",
                                      "B01001C_002E": "Male Native American",
                                      "B01001C_017E": "Female Native American",
                                      "B01001D_002E": "Male Asian",
                                      "B01001D_017E": "Female Asian",
                                      "B01001E_002E": "Male Pacific Islander",
                                      "B01001E_017E": "Female Pacific Islander",
                                      "B01001F_002E": "Male Some Other Race",
                                      "B01001F_017E": "Female Some Other Race",
                                      "B01001G_002E": "Male Two or More Races",
                                      "B01001G_017E": "Female Two or More Races",
                                      "B01001H_002E": "Male White Not Hispanic",
                                      "B01001H_017E": "Female White Not Hispanic",
                                      "B01001I_002E": "Male Hispanic",
                                      "B01001I_017E": "Female Hispanic", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * census_pd["Poverty Count"].astype(int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["Postcode", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate",
                       "Race White",
                       "Race African American",
                       "Race American Indian",
                       "Race Asian",
                       "Race Pacific Islander",
                       "Race Some Other",
                       "Race Two or More",
                       "Race Two or More Including Some Other",
                       "Race Two or More Excluding Some Other",
                       "Male White",
                       "Female White",
                       "Male African",
                       "Female African",
                       "Male Native American",
                       "Female Native American",
                       "Male Asian",
                       "Female Asian",
                       "Male Pacific Islander",
                       "Female Pacific Islander",
                       "Male Some Other Race",
                       "Female Some Other Race",
                       "Male Two or More Races",
                       "Female Two or More Races",
                       "Male White Not Hispanic",
                       "Female White Not Hispanic",
                       "Male Hispanic",
                       "Female Hispanic"]]
print(len(census_pd))
# Out:
# 33120

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_pd.to_csv("census_data_2015.csv", encoding="utf-8", index=False)
