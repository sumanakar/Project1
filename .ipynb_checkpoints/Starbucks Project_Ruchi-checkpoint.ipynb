# %%
# import all the dependencies
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import requests as req
import time
from scipy.stats import norm

# %%
# Read the csv file starbucks_vs_cafe_count.csv
starbucks_usa = pd.read_csv("starbucks_usa.csv")
starbucks_usa.head()
# Out:
#        Brand  Store Number Ownership Type       City State/Province Country  \
# 0  Starbucks   3513-125945       Licensed  Anchorage             AK      US
# 1  Starbucks   74352-84449       Licensed  Anchorage             AK      US
# 2  Starbucks  12449-152385       Licensed  Anchorage             AK      US
# 3  Starbucks  24936-233524  Company Owned  Anchorage             AK      US
# 4  Starbucks    8973-85630  Company Owned  Anchorage             AK      US
#
#    Postcode  Longitude  Latitude New_Country_Code  Avg_Temp_celcius  \
# 0   99504.0    -149.78     61.21              USA          7.939524
# 1   99507.0    -149.84     61.14              USA          7.939524
# 2   99515.0    -149.85     61.11              USA          7.939524
# 3   99515.0    -149.89     61.13              USA          7.939524
# 4   99515.0    -149.86     61.14              USA          7.939524
#
#        Continent
# 0  North America
# 1  North America
# 2  North America
# 3  North America
# 4  North America

# %%
# State with most number of starbucks
starbucks_usa['State/Province'].value_counts().head(1)
# Out:
# CA    2821
# Name: State/Province, dtype: int64

# %%
# Top 10 States in USA based on number of stores
starbucks_usa['State/Province'].value_counts().head(10)
# Out:
# CA    2821
# TX    1042
# WA     757
# FL     694
# NY     645
# IL     575
# AZ     488
# CO     481
# VA     432
# OH     378
# Name: State/Province, dtype: int64

# %%
# Create a plot for top 10 states in USA based on number of stores
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set(title="Top 10 States in USA with most number of stores")
starbucks_usa['State/Province'].value_counts().head(10).plot(kind="bar", color='g')
# starbucks_usa['State/Province'].value_counts().head(25).plot(kind="bar")
plt.savefig("Number of Starbucks in Top 10 States(USA).png")
plt.show()

# %%
# Read another csv file with additional data (census data)
starbucks_usa_df = pd.read_csv("State_Zip.csv")
# Visualize
starbucks_usa_df.head()
# Out:
#    Unnamed: 0 State/Province  Postcode  Store Number             City Country  \
# 0           0             AK     99501             2        Anchorage      US
# 1           1             AK     99502             4        Anchorage      US
# 2           2             AK     99503             1        Anchorage      US
# 3           3             AK     99504             5        Anchorage      US
# 4           4             AK     99505             1  Fort Richardson      US
#
#    Population  Median Age  Household Income  Per Capita Income      ...       \
# 0       17213        38.3             54579              39690      ...
# 1       23649        32.8             87250              39021      ...
# 2       14107        34.0             46819              27693      ...
# 3       42189        31.3             77132              31811      ...
# 4        6479        21.6             51582              19267      ...
#
#    Race White  Race African American  Race American Indian  Race Asian  \
# 0        9757                   1744                  2194        1114
# 1       16743                    950                  1428        1491
# 2        7346                   1231                  1148        2024
# 3       23243                   4529                  3233        4430
# 4        4429                    922                    39         181
#
#    Race Pacific Islander  Race Two or More  perCapitaCategory  \
# 0                    416              3187                  2
# 1                    198              4441                  2
# 2                    631              2622                  1
# 3                   1081             10362                  1
# 4                     13              1350                  1
#
#       perCapitaBinned  ageCategory     ageBinned
# 0  (36977.2, 73954.4]            3  (35.8, 53.7]
# 1  (36977.2, 73954.4]            2  (17.9, 35.8]
# 2      (0.0, 36977.2]            2  (17.9, 35.8]
# 3      (0.0, 36977.2]            2  (17.9, 35.8]
# 4      (0.0, 36977.2]            2  (17.9, 35.8]
#
# [5 rows x 23 columns]

# %% [markdown]
# # Spread of Starbucks Stores in USA as per location : Longitude vs Latitude

# %%
# Create a plot to show the spread of Starbucks stores throughout the country(USA)

# Create lists for coordinates
longitude = list(starbucks_usa_df["Longitude"])
latitude = list(starbucks_usa_df["Latitude"])

g = sns.JointGrid(x="Longitude", y="Latitude", data=starbucks_usa_df, size=10)
g = g.plot_joint(plt.scatter, color="g", edgecolor="white")
g = g.plot_marginals(sns.distplot, kde=False, color="g")

# Chart title
plt.title("Spread of Starbucks Stores in USA")
# x label
plt.xlabel("Longitude")
# y label
plt.ylabel("Latitude")
# Legend
plt.legend("")

# Save an image of the chart and print to screen
plt.savefig("Spread of Starbucks Stores in USA")
plt.show()

# %% [markdown]
# # How competitive is the coffee shop market in regards to Starbucks?

# %% [markdown]
# ## Total number of Starbucks vs Nearby Cafes

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(starbucks_vs_cafe_count['Postcode'], starbucks_vs_cafe_count['Nearby Cafes'], alpha=0.7, edgecolor='black', c="yellow", label="Nearby Cafes")

plt.scatter(starbucks_vs_cafe_count['Postcode'], starbucks_vs_cafe_count['Starbucks'], alpha=0.3, edgecolor='black', c="green", label="Starbucks Count")

plt.legend(loc="upper left", frameon=True, fontsize=10)
plt.xlabel("Zip Code")
plt.ylabel("Count")
plt.title("Starbucks vs Nearby Cafes")
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig("Starbucks vs Nearby Cafes.png")

# %%
# Read the csv file starbucks_vs_cafe_count.csv
starbucks_vs_cafe_count = pd.read_csv("starbucks_vs_cafe_count.csv")
starbucks_vs_cafe_count = starbucks_vs_cafe_count.rename(columns={"Starbucks Count":"Starbucks","Cafe Count":"Nearby Cafes"})
# Visualize the data frame
starbucks_vs_cafe_count.head()
# Out:
#   State/Province  Postcode  Starbucks             City Country  Latitude  \
# 0             AK     99501          2        Anchorage      US     61.22
# 1             AK     99502          4        Anchorage      US     61.18
# 2             AK     99503          1        Anchorage      US     61.18
# 3             AK     99504          5        Anchorage      US     61.23
# 4             AK     99505          1  Fort Richardson      US     61.26
#
#    Longitude  Population  Median Age  Household Income  Per Capita Income  \
# 0    -149.89       17213        38.3             54579              39690
# 1    -149.95       23649        32.8             87250              39021
# 2    -149.88       14107        34.0             46819              27693
# 3    -149.74       42189        31.3             77132              31811
# 4    -149.68        6479        21.6             51582              19267
#
#    Nearby Cafes
# 0            35
# 1            10
# 2            54
# 3             8
# 4             0

# %% [markdown]
# ## Average number of Starbucks and nearby cafes per state

# %%
# Create a dataframe grouped by states with number starbucks and nearby cafes
groupby_states = starbucks_vs_cafe_count.groupby("State/Province").aggregate({"Starbucks":"mean", "Nearby Cafes":"mean"})
groupby_states.head()
# Out:
#                 Starbucks  Nearby Cafes
# State/Province
# AK               2.130435     14.608696
# AL               1.700000      6.620000
# AR               1.527778      6.777778
# AZ               2.757062      7.118644
# CA               3.033333     13.250538

# %%
groupby_states.plot(kind="bar", figsize=(20,10), color=('g','y'), stacked=True,
                    title="Relationship between Starbucks Brand and Nearby Cafes")

plt.savefig("Relationship between Starbucks Brand and Nearby Cafes.png")
plt.show()

# %% [markdown]
# ## Ratio of Starbucks and nearby cafes per state

# %%
# Ratio between Other cafes and Starbucks
ratio = groupby_states["Starbucks"] / groupby_states["Nearby Cafes"] 
ratio.head()
# Out:
# State/Province
# AK    0.145833
# AL    0.256798
# AR    0.225410
# AZ    0.387302
# CA    0.228922
# dtype: float64

# %%
ratio.plot(kind="bar", figsize=(25, 15),title="Ratio between Starbucks Nearby Cafes", align='edge', alpha=.8)
ratio.plot(kind="line", linewidth=3)
plt.savefig("Ratio between Starbucks Nearby Cafes.png")
plt.show()
